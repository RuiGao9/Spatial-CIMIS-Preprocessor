# %%
from cimis_processor import SpatialCIMISProcessor

# %%
# --- Define Paths ---
INPUT_DIR = r"C:\1_Data\CIMIS_Spatial_Downloads"
OUTPUT_DIR = r"C:\1_Data\CIMIS_Processed"

# Initialize the processor with the specified input and output directories
processor = SpatialCIMISProcessor(input_root=INPUT_DIR, output_root=OUTPUT_DIR)

# Run the processing logic
# You can specify a year range
processor.run_pipeline(start_year=2004, end_year=2026)
